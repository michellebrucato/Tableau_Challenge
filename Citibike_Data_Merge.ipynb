# %%
import os
import pandas as pd

feb_df = pd.read_csv("data/JC-202001-citibike-tripdata.csv")
mar_df = pd.read_csv("data/JC-202002-citibike-tripdata.csv")

merged_df = feb_df.merge(mar_df, on=["bikeid"], how='inner')
# merged_df.to_csv("final.csv",index=False)
merged_df.head()

# %%
import csv
import glob
import pandas as pd

# %%
citibike_files = glob.glob("data/*.csv") 
df = pd.concat((pd.read_csv(f, header = 0) for f in citibike_files))
df.shape
# Out:
# (68658, 15)

# %%
df.tail()
# Out:
#        tripduration                 starttime                  stoptime  \
# 26015           544  2020-01-31 23:29:29.3910  2020-01-31 23:38:33.6910
# 26016           122  2020-01-31 23:30:59.3670  2020-01-31 23:33:01.6870
# 26017           201  2020-01-31 23:42:34.8460  2020-01-31 23:45:55.8780
# 26018           300  2020-01-31 23:45:00.6800  2020-01-31 23:50:00.8740
# 26019           721  2020-01-31 23:48:35.1700  2020-02-01 00:00:36.4060
#
#        start station id          start station name  start station latitude  \
# 26015              3213              Van Vorst Park               40.718489
# 26016              3792  Columbus Dr at Exchange Pl               40.716870
# 26017              3273                Manila & 1st               40.721651
# 26018              3185                   City Hall               40.717733
# 26019              3206                     Hilltop               40.731169
#
#        start station longitude  end station id end station name  \
# ...

# %%
# Export merged file as a CSV
df.to_csv("citibike_final.csv")

# %%
# import bitcoin CSV
bit_path = os.path.join("Resources", "bitcoin_cash_price.csv")
bit_df = pd.read_csv(bit_path)

# import dash CSV
dash_path = os.path.join("Resources", "dash_price.csv")
dash_df = pd.read_csv(dash_path)

# merge dataframes together 
combined_df = pd.merge(bit_df, dash_df, how="inner", left_on="Date", right_on="Date", suffixes=("_bitcoin", "_dash"))
combined_df
